# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashshar00/Pandas-Project-Countries-/blob/main/Countries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/Countries (1).zip")

# %%
df
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
df.shape
# Out:
# (227, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    object
#  5   Coastline (coast/area ratio)        227 non-null    object
#  6   Net migration                       224 non-null    object
#  7   Infant mortality (per 1000 births)  224 non-null    object
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    object
#  10  Phones (per 1000)                   223 non-null    object
# ...

# %%
df.describe()
# Out:
#          Population  Area (sq. mi.)  GDP ($ per capita)
# count  2.270000e+02    2.270000e+02          226.000000
# mean   2.874028e+07    5.982270e+05         9689.823009
# std    1.178913e+08    1.790282e+06        10049.138513
# min    7.026000e+03    2.000000e+00          500.000000
# 25%    4.376240e+05    4.647500e+03         1900.000000
# 50%    4.786994e+06    8.660000e+04         5550.000000
# 75%    1.749777e+07    4.418110e+05        15700.000000
# max    1.313974e+09    1.707520e+07        55100.000000

# %%
df[df['Population'] == df['Population'].max()]['Country']
# Out:
# 42    China
# Name: Country, dtype: object

# %%
df[df['Population'] == df['Population'].min()]['Country']
# Out:
# 174    St Pierre & Miquelon
# Name: Country, dtype: object

# %%
df.sort_values(by='Population',ascending=False).head(5)
# Out:
#             Country                               Region  Population  \
# 42           China         ASIA (EX. NEAR EAST)           1313973713
# 94           India         ASIA (EX. NEAR EAST)           1095351995
# 214  United States   NORTHERN AMERICA                      298444215
# 95       Indonesia         ASIA (EX. NEAR EAST)            245452739
# 27          Brazil               LATIN AMER. & CARIB       188078227
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 42          9596960                      136,9                         0,15
# 94          3287590                      333,2                         0,21
# 214         9631420                       31,0                         0,21
# 95          1919440                      127,9                         2,85
# 27          8511965                       22,1                         0,09
#
#     Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df['Region'].value_counts().count()
# Out:
# np.int64(11)

# %%
df['Region'].value_counts(['EASTERN EUROPE'])
# Out:
# Region
# SUB-SAHARAN AFRICA                     0.224670
# LATIN AMER. & CARIB                    0.198238
# ASIA (EX. NEAR EAST)                   0.123348
# WESTERN EUROPE                         0.123348
# OCEANIA                                0.092511
# NEAR EAST                              0.070485
# EASTERN EUROPE                         0.052863
# C.W. OF IND. STATES                    0.052863
# NORTHERN AFRICA                        0.026432
# NORTHERN AMERICA                       0.022026
# BALTICS                                0.013216
# Name: proportion, dtype: float64

# %%
df[df['Region'] == 'EASTERN EUROPE']['Country']
# Out:
# Series([], Name: Country, dtype: object)

# %%
df[df['Population'] == df['Population'].nlargest(2).iloc[1]]
# Out:
#    Country                         Region  Population  Area (sq. mi.)  \
# 94  India   ASIA (EX. NEAR EAST)           1095351995         3287590
#
#    Pop. Density (per sq. mi.) Coastline (coast/area ratio) Net migration  \
# 94                      333,2                         0,21         -0,07
#
#    Infant mortality (per 1000 births)  GDP ($ per capita) Literacy (%)  \
# 94                              56,29              2900.0         59,5
#
#    Phones (per 1000) Arable (%) Crops (%) Other (%) Climate Birthrate  \
# 94              45,4       54,4      2,74     42,86     2,5     22,01
#
#    Deathrate Agriculture Industry Service
# 94      8,18       0,186    0,276   0,538

# %%
asia_df = df[df['Region'] == 'ASIA']

# %%
asia_df[asia_df['Population'] == asia_df['Population'].min()]['Country']
# Out:
# Series([], Name: Country, dtype: object)
